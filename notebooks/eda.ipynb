# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('raw/ADAMS.txt')
# Out:
# C:\Users\campo\AppData\Local\Temp\ipykernel_13332\3755775231.py:1: DtypeWarning: Columns (20,60,66,67,78,79,86,96,103,105,110) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('raw/ADAMS.txt')

# %%
columns_to_remove = ['MIDDLE_NAME',
                     'SUFFIX',
                     'RESIDENTIAL_SECONDARY_ADDR',
                     'RESIDENTIAL_ZIP_PLUS4',
                     'RESIDENTIAL_COUNTRY',
                     'RESIDENTIAL_POSTALCODE',
                     'MAILING_ADDRESS1',
                     'MAILING_SECONDARY_ADDRESS',
                     'MAILING_CITY',
                     'MAILING_STATE',
                     'MAILING_ZIP',
                     'MAILING_ZIP_PLUS4',
                     'MAILING_COUNTRY',
                     'MAILING_POSTAL_CODE',
                     'CAREER_CENTER',
                     'CITY',
                     'CITY_SCHOOL_DISTRICT',
                     'COUNTY_COURT_DISTRICT',
                     'EXEMPTED_VILL_SCHOOL_DISTRICT',
                     'LIBRARY',
                     'MUNICIPAL_COURT_DISTRICT',
                     'PRECINCT_NAME',
                     'PRECINCT_CODE',
                     'TOWNSHIP',
                     'VILLAGE',
                     'WARD']

column_primary_to_remove = ['PRIMARY-03/07/2000', 'PRIMARY-05/07/2002', 'PRIMARY-03/02/2004',
                            'PRIMARY-05/03/2005', 'PRIMARY-09/13/2005', 'PRIMARY-05/02/2006',
                            'PRIMARY-05/08/2007', 'PRIMARY-09/11/2007', 'PRIMARY-11/06/2007',
                            'PRIMARY-03/04/2008', 'PRIMARY-10/14/2008', 'PRIMARY-05/05/2009',
                            'PRIMARY-09/08/2009', 'PRIMARY-09/15/2009', 'PRIMARY-09/29/2009',
                            'PRIMARY-05/04/2010', 'PRIMARY-07/13/2010', 'PRIMARY-09/07/2010',
                            'PRIMARY-05/03/2011', 'PRIMARY-09/13/2011', 'PRIMARY-03/06/2012',
                            'PRIMARY-05/07/2013', 'PRIMARY-09/10/2013', 'PRIMARY-10/01/2013',
                            'PRIMARY-05/06/2014', 'PRIMARY-05/05/2015', 'PRIMARY-09/15/2015',
                            'PRIMARY-03/15/2016', 'PRIMARY-09/13/2016', 'PRIMARY-05/02/2017',
                            'PRIMARY-09/12/2017', 'PRIMARY-05/07/2019', 'PRIMARY-09/10/2019',
                            'PRIMARY-03/17/2020', 'PRIMARY-05/04/2021', 'PRIMARY-08/03/2021', 
                            'PRIMARY-09/14/2021']

# remove columns containing word 'GENERAL' and 'SPECIAL'
df = df.loc[:, ~df.columns.str.contains('GENERAL')]
df = df.loc[:, ~df.columns.str.contains('SPECIAL')]

# removing columns using lists
df.drop(column_primary_to_remove, axis=1, inplace=True)
df.drop(columns_to_remove, axis=1, inplace=True)

# %%
df
# Out:
#         SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID   LAST_NAME   FIRST_NAME  \
# 0      OH0026240622              1      39488       BIGGS        CASEY
# 1      OH0016297398              1      19947  STEPHENSON      TIFFANY
# 2      OH0023282653              1      34477    BOLENDER       PAMELA
# 3      OH0016297435              1       6379     ROWLAND         JANE
# 4      OH0024264643              1      36128    KNECHTLY  CHRISTOPHER
# ...             ...            ...        ...         ...          ...
# 17087  OH0016304448              1       5549      GROOMS       HAROLD
# 17088  OH0024186708              1      35995     MCGOWAN      MALISSA
# 17089  OH0016294595              1      12240      PARKER        FRANK
# 17090  OH0016290400              1       6690      PAYTON         GARY
# 17091  OH0023371504              1      34659    HAMILTON      LEONARD
#
#       DATE_OF_BIRTH REGISTRATION_DATE  VOTER_STATUS PARTY_AFFILIATION  \
# 0        2002-01-18        2021-07-23        ACTIVE               NaN
# 1        1981-10-06        2000-01-27        ACTIVE                 R
# 2        1962-09-29        2015-09-09        ACTIVE               NaN
# 3        1958-04-07        1991-02-07        ACTIVE                 R
# 4        1984-04-24        2017-05-01        ACTIVE               NaN
# ...             ...               ...           ...               ...
# 17087    1946-03-03        1969-09-29        ACTIVE                 R
# 17088    1968-10-03        2017-01-03  CONFIRMATION               NaN
# 17089    1949-03-10        1980-07-15        ACTIVE               NaN
# 17090    1953-07-04        1989-01-01  CONFIRMATION               NaN
# 17091    1990-09-21        2015-11-18        ACTIVE               NaN
#
#        RESIDENTIAL_ADDRESS1 RESIDENTIAL_CITY RESIDENTIAL_STATE  \
# 0            410 E NORTH ST       WEST UNION                OH
# 1             260 MEADOW LN          PEEBLES                OH
# 2               141 VINE ST          PEEBLES                OH
# 3      675 MEASLEY RIDGE RD          PEEBLES                OH
# 4               7768 SR 348       BLUE CREEK                OH
# ...                     ...              ...               ...
# 17087        231 STELLA AVE          PEEBLES                OH
# 17088    3049 TATER KNOB RD          PEEBLES                OH
# 17089           8315 SR 247       WEST UNION                OH
# 17090    1714 BEECH FORK RD          PEEBLES                OH
# 17091           356 COZY LN       WEST UNION                OH
#
#        RESIDENTIAL_ZIP  CONGRESSIONAL_DISTRICT  COURT_OF_APPEALS  \
# 0                45693                       2                 4
# 1                45660                       2                 4
# 2                45660                       2                 4
# 3                45660                       2                 4
# 4                45616                       2                 4
# ...                ...                     ...               ...
# 17087            45660                       2                 4
# 17088            45660                       2                 4
# 17089            45693                       2                 4
# 17090            45660                       2                 4
# 17091            45693                       2                 4
#
#       EDU_SERVICE_CENTER_DISTRICT               LOCAL_SCHOOL_DISTRICT  \
# 0               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 1               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 2               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 3               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 4               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# ...                           ...                                 ...
# 17087           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17088           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17089           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17090           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17091           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
#
#        STATE_BOARD_OF_EDUCATION  STATE_REPRESENTATIVE_DISTRICT  \
# 0                            10                             90
# 1                            10                             90
# 2                            10                             90
# 3                            10                             90
# 4                            10                             90
# ...                         ...                            ...
# 17087                        10                             90
# 17088                        10                             90
# 17089                        10                             90
# 17090                        10                             90
# 17091                        10                             90
#
#        STATE_SENATE_DISTRICT PRIMARY-05/08/2018 PRIMARY-05/03/2022
# 0                         14                NaN                NaN
# 1                         14                NaN                  R
# 2                         14                NaN                NaN
# 3                         14                NaN                  R
# 4                         14                NaN                NaN
# ...                      ...                ...                ...
# 17087                     14                  R                  R
# 17088                     14                NaN                NaN
# 17089                     14                NaN                NaN
# 17090                     14                NaN                NaN
# 17091                     14                NaN                NaN
#
# [17092 rows x 22 columns]

# %%
plt.hist(df['COUNTY_ID'])
# Out:
# (array([1298., 1245., 1274., 1176., 1068., 1432., 1660., 1935., 2548.,
#         3456.]),
#  array([5.00000e+00, 4.00950e+03, 8.01400e+03, 1.20185e+04, 1.60230e+04,
#         2.00275e+04, 2.40320e+04, 2.80365e+04, 3.20410e+04, 3.60455e+04,
#         4.00500e+04]),
#  <BarContainer object of 10 artists>)

# %%
# in 'PRIMARY-05/08/2018' replace Nan with 'X'
df['PRIMARY-05/08/2018'] = df['PRIMARY-05/08/2018'].fillna('X')
df
# Out:
#         SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID   LAST_NAME   FIRST_NAME  \
# 0      OH0026240622              1      39488       BIGGS        CASEY
# 1      OH0016297398              1      19947  STEPHENSON      TIFFANY
# 2      OH0023282653              1      34477    BOLENDER       PAMELA
# 3      OH0016297435              1       6379     ROWLAND         JANE
# 4      OH0024264643              1      36128    KNECHTLY  CHRISTOPHER
# ...             ...            ...        ...         ...          ...
# 17087  OH0016304448              1       5549      GROOMS       HAROLD
# 17088  OH0024186708              1      35995     MCGOWAN      MALISSA
# 17089  OH0016294595              1      12240      PARKER        FRANK
# 17090  OH0016290400              1       6690      PAYTON         GARY
# 17091  OH0023371504              1      34659    HAMILTON      LEONARD
#
#       DATE_OF_BIRTH REGISTRATION_DATE  VOTER_STATUS PARTY_AFFILIATION  \
# 0        2002-01-18        2021-07-23        ACTIVE               NaN
# 1        1981-10-06        2000-01-27        ACTIVE                 R
# 2        1962-09-29        2015-09-09        ACTIVE               NaN
# 3        1958-04-07        1991-02-07        ACTIVE                 R
# 4        1984-04-24        2017-05-01        ACTIVE               NaN
# ...             ...               ...           ...               ...
# 17087    1946-03-03        1969-09-29        ACTIVE                 R
# 17088    1968-10-03        2017-01-03  CONFIRMATION               NaN
# 17089    1949-03-10        1980-07-15        ACTIVE               NaN
# 17090    1953-07-04        1989-01-01  CONFIRMATION               NaN
# 17091    1990-09-21        2015-11-18        ACTIVE               NaN
#
#        RESIDENTIAL_ADDRESS1 RESIDENTIAL_CITY RESIDENTIAL_STATE  \
# 0            410 E NORTH ST       WEST UNION                OH
# 1             260 MEADOW LN          PEEBLES                OH
# 2               141 VINE ST          PEEBLES                OH
# 3      675 MEASLEY RIDGE RD          PEEBLES                OH
# 4               7768 SR 348       BLUE CREEK                OH
# ...                     ...              ...               ...
# 17087        231 STELLA AVE          PEEBLES                OH
# 17088    3049 TATER KNOB RD          PEEBLES                OH
# 17089           8315 SR 247       WEST UNION                OH
# 17090    1714 BEECH FORK RD          PEEBLES                OH
# 17091           356 COZY LN       WEST UNION                OH
#
#        RESIDENTIAL_ZIP  CONGRESSIONAL_DISTRICT  COURT_OF_APPEALS  \
# 0                45693                       2                 4
# 1                45660                       2                 4
# 2                45660                       2                 4
# 3                45660                       2                 4
# 4                45616                       2                 4
# ...                ...                     ...               ...
# 17087            45660                       2                 4
# 17088            45660                       2                 4
# 17089            45693                       2                 4
# 17090            45660                       2                 4
# 17091            45693                       2                 4
#
#       EDU_SERVICE_CENTER_DISTRICT               LOCAL_SCHOOL_DISTRICT  \
# 0               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 1               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 2               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 3               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 4               SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# ...                           ...                                 ...
# 17087           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17088           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17089           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17090           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
# 17091           SOUTHERN OHIO ESC  ADAMS COUNTY/OH VALLEY LSD (ADAMS)
#
#        STATE_BOARD_OF_EDUCATION  STATE_REPRESENTATIVE_DISTRICT  \
# 0                            10                             90
# 1                            10                             90
# 2                            10                             90
# 3                            10                             90
# 4                            10                             90
# ...                         ...                            ...
# 17087                        10                             90
# 17088                        10                             90
# 17089                        10                             90
# 17090                        10                             90
# 17091                        10                             90
#
#        STATE_SENATE_DISTRICT PRIMARY-05/08/2018 PRIMARY-05/03/2022
# 0                         14                  X                  X
# 1                         14                  X                  R
# 2                         14                  X                  X
# 3                         14                  X                  R
# 4                         14                  X                  X
# ...                      ...                ...                ...
# 17087                     14                  R                  R
# 17088                     14                  X                  X
# 17089                     14                  X                  X
# 17090                     14                  X                  X
# 17091                     14                  X                  X
#
# [17092 rows x 22 columns]

# %%
df['PRIMARY-05/08/2018'].unique()
# Out:
# array(['X', 'R', 'D', 'G'], dtype=object)

# %%
colors = []
for lab,row in df.iterrows():
    if row['PRIMARY-05/08/2018'] == 'X':
        colors.append('white')
    elif row['PRIMARY-05/08/2018'] == 'R':
        colors.append('red')
    elif row['PRIMARY-05/08/2018'] == 'D':
        colors.append('blue')
    elif row['PRIMARY-05/08/2018'] == 'G':
        colors.append('green')
